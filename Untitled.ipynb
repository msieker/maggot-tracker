# %%
from pymongo import MongoClient
client = MongoClient("mongodb://root:password@localhost:27017")

db = client['maggot-tracker']
tweet_collection = db.tweets
user_collection = db.users

# %%
import itertools
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, TweetTokenizer
from collections import Counter
from word_cloud.word_cloud_generator import WordCloud
from IPython.core.display import HTML
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import pandas as pd
import unicodedata

# %%
tk = TweetTokenizer()
all_stopwords = stopwords.words('english')
all_stopwords += ['!', '.', '[', ']', 'the', 'to', 'rt', ':', '...', '…', ',', '’', '“', '‘', '#', '?', 'u', 's', '"', "'", "-", "/", "”", '(', ')', "&", '*','🇺', '🇸', '@realdonaldtrump', 'q', 'trump']

with open('tagwatch.txt', 'r') as f:
    all_stopwords += [l.strip().lower() for l in f.readlines()]

tweet_text = list(tweet_collection.find(projection={'text': True}))
print('using', len(tweet_text), 'tweets')
cv = CountVectorizer(stop_words=all_stopwords, tokenizer=tk.tokenize, analyzer='word')
word_count_vector = cv.fit_transform([" ".join(list([unicodedata.normalize('NFKD', t['text']).lower() for t in tweet_text]))])
max = np.max(word_count_vector)
word_count_vector = np.multiply(word_count_vector, 1/(max))
coo_matrix = word_count_vector.tocoo()
tuples = zip(coo_matrix.col, coo_matrix.data)
sorted_tuples = sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

feature_names = cv.get_feature_names()
counts = [[feature_names[idx], score] for idx, score in sorted_tuples]
df = pd.DataFrame(counts[:100], columns=['words', 'score'])
wc = WordCloud()
embed = wc.get_embed_code(text_scores=df)
HTML(embed)
# Out:
# using 63382 tweets
# ...

# %%
tk = TweetTokenizer()
all_stopwords = stopwords.words('english')
all_stopwords += ['!', '.', '[', ']', 'the', 'to', 'rt', ':', '...', '…', ',', '’', '“', '‘', '#', '?', 'u', 's', '"', "'", "-", "/", "”", '(', ')', "&", '*','🇺', '🇸', '@realdonaldtrump', 'q', 'trump']

with open('tagwatch.txt', 'r') as f:
    all_stopwords += [l.strip().lower() for l in f.readlines()]

tweet_text = list(user_collection.find(projection={'description': True}))
print('using', len(tweet_text), 'users')
cv = CountVectorizer(stop_words=all_stopwords, tokenizer=tk.tokenize, analyzer='word')
word_count_vector = cv.fit_transform([" ".join(list([unicodedata.normalize('NFKD', t['description']).lower() for t in tweet_text if t['description']]))])
max = np.max(word_count_vector)
word_count_vector = np.multiply(word_count_vector, 1/(max))
coo_matrix = word_count_vector.tocoo()
tuples = zip(coo_matrix.col, coo_matrix.data)
sorted_tuples = sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

feature_names = cv.get_feature_names()
counts = [[feature_names[idx], score] for idx, score in sorted_tuples]
df = pd.DataFrame(counts[:100], columns=['words', 'score'])
wc = WordCloud()
embed = wc.get_embed_code(text_scores=df)
HTML(embed)
# Out:
# using 29666 users
# ...

# %%
tk = TweetTokenizer()
all_stopwords = stopwords.words('english')
all_stopwords += ['!', '.', '[', ']', 'the', 'to', 'rt', ':', '...', '…', ',', '’', '“', '‘', '#', '?', 'u', 's', '"', "'", "-", "/", "”", '(', ')', "&", '*','🇺', '🇸', '@realdonaldtrump', 'q', 'trump']
watched_tags = []
with open('tagwatch.txt', 'r') as f:
    pass
    #watched_tags = [l.strip().lower() for l in f.readlines()]

tweet_text = list(tweet_collection.find(projection={'text': True}))
print('using', len(tweet_text), 'tweets')

parsed_tweets = [tk.tokenize(unicodedata.normalize('NFKD', t['text']).lower()) for t in tweet_text]
hashtags = [[w for w in t if w.startswith('#') and w not in watched_tags] for t in parsed_tweets]
merged = list(itertools.chain.from_iterable(hashtags))
counts = sorted([{"tag":k, "count":v} for k,v in Counter(merged).items()], key=lambda c: c['count'], reverse=True)
for i in counts:
    print(i['tag'] + ": " + str(i['count']))
# Out:
# using 62481 tweets
# #qanon: 13105
# #wwg1wga: 8692
# #maga: 5512
# #: 1637
# #kag: 1338
# #qarmy: 1106
# #wearethenewsnow: 1057
# #oann: 998
# #trump2020: 910
# #wwg1wgaworldwide: 884
# #factsmatter: 786
# #flynnexonerated: 655
# #kag2020: 590
# #thegreatawakening: 464
# #wakeupamerica: 461
# #trump: 416
# #q17: 398
# #wwg1gwa: 371
# #voteredtosaveamerica: 368
# #greatawakening: 340
# #qalert: 325
# #walkaway: 305
# #flynn: 304
# #treason: 302
# #darktolight: 297
# #generalflynn: 289
# #inittogether: 280
# #covid19: 264
# #themoreyouknow: 263
# #myhousemyamerica: 223
# #fakenews: 222
# #america: 218
# #qano: 218
# #qpost: 217
# #flagsoutforflynn: 192
# #magarollercoaster: 181
# #qposts: 176
# #patriots: 176
# #potus: 175
# #deepstate: 170
# #inthistogether: 170
# #enationtrains: 169
# #flynnfighters: 167
# #democrats: 159
# #digitalsoldier: 156
# #coronavirus: 151
# #wwg1wga_worldwide: 150
# #fieldoffight: 148
# #patriotsfigh: 148
# #maga2020: 146
# #patriotstriketeam: 143
# ...
